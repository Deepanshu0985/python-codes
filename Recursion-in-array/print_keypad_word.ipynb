# %%
keys = {'1':"",'2':'abc','3':'def','4':'ghi','5':'jkl','6':'mno','7':'pqr','8':'stuv','9':'wxyz'}

# %%
def print_word(input):
    if input =='':
        return ['']
    ans = []
    inputword = print_word(input[1:])
    keyletter = keys[input[0]]
    for word in inputword:
        for char in keyletter:
            ans.append(char+word)
    return ans

# %%
ans = print_word('23345')
ans
# Out:
# ['addgj',
#  'bddgj',
#  'cddgj',
#  'aedgj',
#  'bedgj',
#  'cedgj',
#  'afdgj',
#  'bfdgj',
#  'cfdgj',
#  'adegj',
#  'bdegj',
#  'cdegj',
#  'aeegj',
#  'beegj',
#  'ceegj',
#  'afegj',
#  'bfegj',
#  'cfegj',
#  'adfgj',
#  'bdfgj',
#  'cdfgj',
#  'aefgj',
#  'befgj',
#  'cefgj',
#  'affgj',
#  'bffgj',
#  'cffgj',
#  'addhj',
#  'bddhj',
#  'cddhj',
#  'aedhj',
#  'bedhj',
#  'cedhj',
#  'afdhj',
#  'bfdhj',
#  'cfdhj',
#  'adehj',
#  'bdehj',
#  'cdehj',
#  'aeehj',
#  'beehj',
#  'ceehj',
#  'afehj',
#  'bfehj',
#  'cfehj',
#  'adfhj',
#  'bdfhj',
#  'cdfhj',
#  'aefhj',
#  'befhj',
#  'cefhj',
#  'affhj',
#  'bffhj',
#  'cffhj',
#  'addij',
#  'bddij',
#  'cddij',
#  'aedij',
#  'bedij',
#  'cedij',
#  'afdij',
#  'bfdij',
#  'cfdij',
#  'adeij',
#  'bdeij',
#  'cdeij',
#  'aeeij',
#  'beeij',
#  'ceeij',
#  'afeij',
#  'bfeij',
#  'cfeij',
#  'adfij',
#  'bdfij',
#  'cdfij',
#  'aefij',
#  'befij',
#  'cefij',
#  'affij',
#  'bffij',
#  'cffij',
#  'addgk',
#  'bddgk',
# ...
